# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="59znzY448C1kIAKz9kyv")
project = rf.workspace("ars-rcuds").project("deteksi-apd-fnrng-fs1ot")
version = project.version(9)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install ultralytics
from ultralytics import YOLO

# Load a pre-trained YOLOv8n model
model = YOLO('yolov8n.pt')

# Train the model with specified parameters
model.train(
    data=f'{dataset.location}/data.yaml',
    epochs=100,
    imgsz=640,
    batch=16,
    project='PPE_Detection_Training',
    name='yolov8n_ppe_100epochs'
)

# %%
# !pip install ultralytics
from ultralytics import YOLO

model = YOLO('last.pt')

model.train(
    data=f'{dataset.location}/data.yaml',
    epochs=100,      # Tambah 100 lagi
    imgsz=640,
    lr0=0.001,       # Perkecil dikit dari default (0.01)
    augment=True,    # Pakai augmentasi bawaan
    mosaic=1.0,      # Paksa mosaic aktif terus
    mixup=0.2,       # Tambah mixup kalau objeknya sering tumpang tindih
    project='PPE_Detection_Training',
    name='yolov8n_ppe_retrain'
)
